# %%
import sys
sys.path.insert(1, '../src')

from get_manifesto import *
from jnry import Jnry

import pandas as pd
import logging
import requests
from config import manifesto_key

# %% [markdown]
# ## 1. Using the manifesto API
#
# ### 1a. Get an overview of available countries.

# %%
VERSION = "MPDS2021a"

a = Manifesto_data(VERSION, manifesto_key)
meta_data = a.get_meta_data()
meta_data.head()
# Out:
# INFO:root:Available version numbers: ['MPDS2012a', 'MPDS2012b', 'MPDS2013a', 'MPDS2013b', 'MPDS2014a', 'MPDS2014b', 'MPDS2015a', 'MPDS2016a', 'MPDS2016b', 'MPDS2017a', 'MPDS2017b', 'MPDS2018a', 'MPDS2018b', 'MPDS2019a', 'MPDS2019b', 'MPDS2020a', 'MPDS2020b', 'MPDS2021a']
# INFO:root:The most recent version number is: MPDS2021a.
#
# INFO:root:The most recent available version number (MPDS2021a) is the same as the version you've initialized (MPDS2021a)
# INFO:root:Available countries:
#
# ['Sweden', 'Norway', 'Denmark', 'Finland', 'Iceland', 'Belgium', 'Netherlands', 'Luxembourg', 'France', 'Italy', 'Spain', 'Greece', 'Portugal', 'Germany', 'Austria', 'Switzerland', 'United Kingdom', 'Northern Ireland', 'Ireland', 'Malta', 'Cyprus', 'United States', 'Canada', 'Australia', 'New Zealand', 'Japan', 'Israel', 'Sri Lanka', 'Turkey', 'Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia-Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic', 'Estonia', 'Georgia', 'German Democratic Republic', 'Hungary', 'Latvia', 'Lithuania', 'North Macedonia', 'Moldova', 'Montenegro', 'Poland', 'Romania', 'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Ukraine', 'South Korea', 'Mexico', 'South Africa']
# INFO:root:Available time periods:
#
# [1944, 1948, 1952, 1956, 1958, 1960, 1964, 1968, 1970, 1973, 1976, 1979, 1982, 1985, 1988, 1991, 1994, 1998, 2002, 2006, 2010, 2014, 2018, 1945, 1949, 1953, 1957, 1961, 1965, 1969, 1977, 1981, 1989, 1993, 1997, 2001, 2005, 2009, 2013, 2017, 1947, 1950, 1966, 1971, 1975, 1984, 1987, 1990, 2007, 2011, 2015, 2019, 1951, 1954, 1962, 1972, 1983, 1995, 1999, 2003, 1946, 1959, 1963, 1967, 1974, 1978, 2016, 1986, 2012, 2004, 1992, 1996, 2008, 2000, 1980, 2021, 1955, 1921, 1925, 1929, 1933, 1938, 1920, 1924, 1928, 1932, 1936, 1940, 2020]
#   country countryname oecdmember eumember      edate    date  party  \
# 0      11      Sweden          0        0 1944-09-17  194409  11220
# 1      11      Sweden          0        0 1944-09-17  194409  11320
# 2      11      Sweden          0        0 1944-09-17  194409  11420
# 3      11      Sweden          0        0 1944-09-17  194409  11620
# 4      11      Sweden          0        0 1944-09-17  194409  11810
#
#                         partyname partyabbrev parfam  ... per703_1 per703_2  \
# 0       Communist Party of Sweden         SKP     20  ...     None     None
# 1  Social Democratic Labour Party         SAP     30  ...     None     None
# 2                  People’s Party          FP     40  ...     None     None
# 3                     Right Party                 60  ...     None     None
# 4                  Agrarian Party                 80  ...     None     None
#
#     rile planeco markeco welfare           intpeace datasetversion id_perm  \
# 0    9.6     1.9     1.9       0                1.9          2021a  JN1LZH
# 1  -37.8     3.3     2.2    33.4  5.600000000000001          2021a  CMR7F6
# 2    9.5     3.2     6.4    14.3                1.6          2021a  Z6OL6C
# 3     28     1.8    22.8    10.6                  0          2021a  YMKVN2
# 4  23.81       0  19.048       0              4.762          2021a  U4SCRD
#
#    year
# 0  1944
# 1  1944
# 2  1944
# 3  1944
# 4  1944
#
# [5 rows x 175 columns]

# %% [markdown]
# ### 1b. Get available years for a particular country.

# %%
a.get_country_specific_df('Norway')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:root:You requested a specific df of the Norway.
#
# For this country, the following years are available: [1953, 1957, 1961, 1965, 1969, 1973, 1977, 1981, 1985, 1989, 1993, 1997, 2001, 2005, 2009, 2013, 2017]

# %% [markdown]
# ### 1c. Get annotated dataset for selected timeframe + country
# Please note that if you leave `timeframe` empty, you will get all available data for the specified country.

# %%
norway = a.get_annotations_per_country("Norway", timeframe= [2009, 2013, 2017])
# Out:
# INFO:root:You requested a specific df of the Norway.
#
# For this country, the following years are available: [1953, 1957, 1961, 1965, 1969, 1973, 1977, 1981, 1985, 1989, 1993, 1997, 2001, 2005, 2009, 2013, 2017]
# INFO:root:Specific timeframes included. Starting to collect data from those timeframes next.
# WARNING:root:This is not here: 200909-->Norwegian Communist Party
# INFO:root:Succesfully added: 200909-->Labour Party
# INFO:root:Succesfully added: 200909-->Liberal Party
# INFO:root:Succesfully added: 200909-->Christian People’s Party
# INFO:root:Succesfully added: 200909-->Conservative Party
# INFO:root:Succesfully added: 200909-->Centre Party
# INFO:root:Succesfully added: 200909-->Socialist Left Party
# WARNING:root:This is not here: 200909-->New People’s Party
# INFO:root:Succesfully added: 200909-->Progress Party
# WARNING:root:This is not here: 200909-->Green Party
# WARNING:root:This is not here: 200909-->Red Party
# WARNING:root:This is not here: 201309-->Norwegian Communist Party
# INFO:root:Succesfully added: 201309-->Labour Party
# INFO:root:Succesfully added: 201309-->Liberal Party
# INFO:root:Succesfully added: 201309-->Christian People’s Party
# INFO:root:Succesfully added: 201309-->Conservative Party
# INFO:root:Succesfully added: 201309-->Centre Party
# INFO:root:Succesfully added: 201309-->Socialist Left Party
# WARNING:root:This is not here: 201309-->New People’s Party
# INFO:root:Succesfully added: 201309-->Progress Party
# INFO:root:Succesfully added: 201309-->Green Party
# WARNING:root:This is not here: 201309-->Red Party
# WARNING:root:This is not here: 201709-->Norwegian Communist Party
# INFO:root:Succesfully added: 201709-->Labour Party
# INFO:root:Succesfully added: 201709-->Liberal Party
# INFO:root:Succesfully added: 201709-->Christian People’s Party
# INFO:root:Succesfully added: 201709-->Conservative Party
# INFO:root:Succesfully added: 201709-->Centre Party
# INFO:root:Succesfully added: 201709-->Socialist Left Party
# WARNING:root:This is not here: 201709-->New People’s Party
# INFO:root:Succesfully added: 201709-->Progress Party
# INFO:root:Succesfully added: 201709-->Green Party
# INFO:root:Succesfully added: 201709-->Red Party

# %% [markdown]
# ## 2. Merge met PartyFact data
# ### 2a. Create an instance of the `Jnry` class.

# %%
j = Jnry(country='Norway', df=norway, source='CMP')
# Out:
# INFO:root:Processing a CMP file with data from Norway.

# %% [markdown]
# ### 2b. Created merged df.

# %%
df = j.merge_party_facts_with_target()
# Out:
# INFO:root:exact and fuzzy matching will start now for the following target data:
# INFO:root:['Centre Party : 2009', 'Centre Party : 2013', 'Centre Party : 2017', 'Christian People’s Party : 2009', 'Christian People’s Party : 2013', 'Christian People’s Party : 2017', 'Conservative Party : 2009', 'Conservative Party : 2013', 'Conservative Party : 2017', 'Green Party : 2013', 'Green Party : 2017', 'Labour Party : 2009', 'Labour Party : 2013', 'Labour Party : 2017', 'Liberal Party : 2009', 'Liberal Party : 2013', 'Liberal Party : 2017', 'Progress Party : 2009', 'Progress Party : 2013', 'Progress Party : 2017', 'Red Party : 2017', 'Socialist Left Party : 2009', 'Socialist Left Party : 2013', 'Socialist Left Party : 2017']
# INFO:root:Starting matching for Centre Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Centre Party <---> Green Party(= PF name), 70% certainty.
# INFO:root:Starting matching for Centre Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Centre Party <---> Green Party(= PF name), 70% certainty.
# INFO:root:Starting matching for Centre Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Centre Party <---> Green Party(= PF name), 70% certainty.
# INFO:root:Starting matching for Christian People’s Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Christian People’s Party <---> Christian Democratic Party(= PF name), 72% certainty.
# INFO:root:Starting matching for Christian People’s Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Christian People’s Party <---> Christian Democratic Party(= PF name), 72% certainty.
# INFO:root:Starting matching for Christian People’s Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Christian People’s Party <---> Christian Democratic Party(= PF name), 72% certainty.
# INFO:root:Starting matching for Conservative Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchConservative Party <---> Conservative Party(= PF name)
# INFO:root:Starting matching for Conservative Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchConservative Party <---> Conservative Party(= PF name)
# INFO:root:Starting matching for Conservative Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchConservative Party <---> Conservative Party(= PF name)
# INFO:root:Starting matching for Green Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchGreen Party <---> Green Party(= PF name)
# INFO:root:Starting matching for Green Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchGreen Party <---> Green Party(= PF name)
# INFO:root:Starting matching for Labour Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Labour Party <---> Norwegian Labour Party(= PF name), 71% certainty.
# INFO:root:Starting matching for Labour Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Labour Party <---> Norwegian Labour Party(= PF name), 71% certainty.
# INFO:root:Starting matching for Labour Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Labour Party <---> Norwegian Labour Party(= PF name), 71% certainty.
# INFO:root:Starting matching for Liberal Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Liberal Party <---> Liberal Left Party(= PF name), 84% certainty.
# INFO:root:Starting matching for Liberal Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Liberal Party <---> Liberal Left Party(= PF name), 84% certainty.
# INFO:root:Starting matching for Liberal Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Fuzzy match Liberal Party <---> Liberal Left Party(= PF name), 84% certainty.
# INFO:root:Starting matching for Progress Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchProgress Party <---> Progress Party(= PF name)
# INFO:root:Starting matching for Progress Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchProgress Party <---> Progress Party(= PF name)
# INFO:root:Starting matching for Progress Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchProgress Party <---> Progress Party(= PF name)
# INFO:root:Starting matching for Red Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchRed Party <---> Red Party(= PF name)
# INFO:root:Starting matching for Socialist Left Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchSocialist Left Party <---> Socialist Left Party(= PF name)
# INFO:root:Starting matching for Socialist Left Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchSocialist Left Party <---> Socialist Left Party(= PF name)
# INFO:root:Starting matching for Socialist Left Party.......
# INFO:root:the length of the slice of the partyfact data is: 33
# INFO:root:Exact matchSocialist Left Party <---> Socialist Left Party(= PF name)

# %%
df.head()
# Out:
#                                                 text cmp_code eu_code  \
# 0                                      Skape og dele       NA      NA
# 1               Arbeiderpartiets program 2009 – 2013       NA      NA
# 2  Vedtatt på Arbeiderpartiets landsmøte 18. – 21...       NA      NA
# 3  Les mer om vår politikk på www.arbeiderpartiet...       NA      NA
# 4                    Arbeiderpartiet.no/partiprogram       NA      NA
#
#   party_id     partyname timeperiod  year  jnry_year country_iso  \
# 0    12320  Labour Party     200909  2009       2009         NOR
# 1    12320  Labour Party     200909  2009       2009         NOR
# 2    12320  Labour Party     200909  2009       2009         NOR
# 3    12320  Labour Party     200909  2009       2009         NOR
# 4    12320  Labour Party     200909  2009       2009         NOR
#
#    partyfacts_id           partyfacts_name partyfacts_name_short  \
# 0            448  Det norske Arbeiderparti                   DNA
# 1            448  Det norske Arbeiderparti                   DNA
# 2            448  Det norske Arbeiderparti                   DNA
# 3            448  Det norske Arbeiderparti                   DNA
# 4            448  Det norske Arbeiderparti                   DNA
#
#   partyfacts_name_english                                          wikipedia  \
# 0  Norwegian Labour Party  https://en.wikipedia.org/wiki/Det_Norske_Arbei...
# 1  Norwegian Labour Party  https://en.wikipedia.org/wiki/Det_Norske_Arbei...
# 2  Norwegian Labour Party  https://en.wikipedia.org/wiki/Det_Norske_Arbei...
# 3  Norwegian Labour Party  https://en.wikipedia.org/wiki/Det_Norske_Arbei...
# 4  Norwegian Labour Party  https://en.wikipedia.org/wiki/Det_Norske_Arbei...
#
#   type_of_match  certainty match_found_with_pf_column
# 0         fuzzy       71.0               name_english
# 1         fuzzy       71.0               name_english
# 2         fuzzy       71.0               name_english
# 3         fuzzy       71.0               name_english
# 4         fuzzy       71.0               name_english

# %% [markdown]
# ### 2b. Same, using CMP data file from disk

# %%
## CMP file from disk
j = Jnry(country= 'Spain', path_to_file="spain.csv", source='CMP')
df_spain = j.merge_party_facts_with_target()
df_spain.head()
# Out:
# INFO:root:Processing a CMP file with data from Spain.
# INFO:root:exact and fuzzy matching will start now for the following target data:
# INFO:root:['Andalusian Party : 2004', 'Aragonist Council : 2004', 'Aragonist Council : 2008', 'Basque Nationalist Party : 2008', 'Basque Solidarity : 2008', 'Canarian Coalition–New Canaries : 2004', 'Canarian Coalition–New Canaries : 2008', 'Catalan Republican Left : 2008', 'Convergence and Union : 2004', 'Convergence and Union : 2008', 'Galician Nationalist Bloc : 2004', 'Galician Nationalist Bloc : 2008', "Navarrese People's Union : 2004", "People's Party : 2004", "People's Party : 2008", 'Spanish Socialist Workers’ Party : 2004', 'Spanish Socialist Workers’ Party : 2008', 'United Left : 2004', 'United Left : 2008']
# INFO:root:Starting matching for Andalusian Party.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Exact matchAndalusian Party <---> Andalusian Party(= PF name)
# INFO:root:Starting matching for Aragonist Council.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match Aragonist Council <---> Aragonese Council(= PF name), 88% certainty.
# INFO:root:Starting matching for Aragonist Council.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match Aragonist Council <---> Aragonese Council(= PF name), 88% certainty.
# INFO:root:Starting matching for Basque Nationalist Party.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Exact matchBasque Nationalist Party <---> Basque Nationalist Party(= PF name)
# INFO:root:Starting matching for Basque Solidarity.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Exact matchBasque Solidarity <---> Basque Solidarity(= PF name)
# INFO:root:Starting matching for Canarian Coalition–New Canaries.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match Canarian Coalition–New Canaries <---> Canary Coalition(= PF name), 64% certainty.
# INFO:root:Starting matching for Canarian Coalition–New Canaries.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match Canarian Coalition–New Canaries <---> Canary Coalition(= PF name), 64% certainty.
# INFO:root:Starting matching for Catalan Republican Left.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match Catalan Republican Left <---> Republican Left(= PF name), 79% certainty.
# INFO:root:Starting matching for Convergence and Union.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match Convergence and Union <---> Convergence and Unity(= PF name), 90% certainty.
# INFO:root:Starting matching for Convergence and Union.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match Convergence and Union <---> Convergence and Unity(= PF name), 90% certainty.
# INFO:root:Starting matching for Galician Nationalist Bloc.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match Galician Nationalist Bloc <---> Galician Nationalist Block(= PF name), 98% certainty.
# INFO:root:Starting matching for Galician Nationalist Bloc.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match Galician Nationalist Bloc <---> Galician Nationalist Block(= PF name), 98% certainty.
# INFO:root:Starting matching for Navarrese People's Union.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match Navarrese People's Union <---> Navarrese Peoples Union(= PF name), 98% certainty.
# INFO:root:Starting matching for People's Party.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match People's Party <---> People's Socialist Party(= PF name), 74% certainty.
# INFO:root:Starting matching for People's Party.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match People's Party <---> People's Socialist Party(= PF name), 74% certainty.
# INFO:root:Starting matching for Spanish Socialist Workers’ Party.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Fuzzy match Spanish Socialist Workers’ Party <---> Spanish Socialist Workers Party(= PF name), 98% certainty.
# INFO:root:Starting matching for Spanish Socialist Workers’ Party.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Fuzzy match Spanish Socialist Workers’ Party <---> Spanish Socialist Workers Party(= PF name), 98% certainty.
# INFO:root:Starting matching for United Left.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Exact matchUnited Left <---> United Left(= PF name)
# INFO:root:Starting matching for United Left.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Exact matchUnited Left <---> United Left(= PF name)
#    Unnamed: 0                                               text  cmp_code  \
# 0           0  ÍNDICE.  PRÓLOGO.................................       NaN
# 1           0  ZAPATERO Presidente.  MERECEMOS UNA ESPAÑA MEJ...       NaN
# 2           0  PROGRAMA DE GOBIERNO DEL PARTIDO POPULAR. ELEC...       NaN
# 3           0                                            Prólogo       NaN
# 4           1  El Partido Andalucista presenta a las andaluza...     305.0
#
#    eu_code  party_id                         partyname  timeperiod  year  \
# 0      NaN     33220                       United Left      200403  2004
# 1      NaN     33320  Spanish Socialist Workers’ Party      200403  2004
# 2      NaN     33610                    People's Party      200403  2004
# 3      NaN     33906                  Andalusian Party      200403  2004
# 4      NaN     33906                  Andalusian Party      200403  2004
#
#    jnry_year country_iso  partyfacts_id                    partyfacts_name  \
# 0       2004         ESP            247                    Izquierda Unida
# 1       2004         ESP           1338  Partido Socialista Obrero Español
# 2       2004         ESP           1687         Partido Socialista Popular
# 3       2004         ESP           1497                Partidu Andalucista
# 4       2004         ESP           1497                Partidu Andalucista
#
#   partyfacts_name_short          partyfacts_name_english  \
# 0                    IU                      United Left
# 1                  PSOE  Spanish Socialist Workers Party
# 2                   PSP         People's Socialist Party
# 3                    PA                 Andalusian Party
# 4                    PA                 Andalusian Party
#
#                                            wikipedia type_of_match  certainty  \
# 0  https://en.wikipedia.org/wiki/United_Left_(Spain)         exact        NaN
# 1  https://en.wikipedia.org/wiki/Spanish_Socialis...         fuzzy       98.0
# 2  https://en.wikipedia.org/wiki/Popular_Socialis...         fuzzy       74.0
# 3     https://en.wikipedia.org/wiki/Andalusian_Party         exact        NaN
# 4     https://en.wikipedia.org/wiki/Andalusian_Party         exact        NaN
#
#   match_found_with_pf_column
# 0               name_english
# 1               name_english
# 2               name_english
# 3               name_english
# 4               name_english

# %% [markdown]
# ### 2c. Same, using CAP data ¶

# %%
path_to_file = 'https://comparativeagendas.s3.amazonaws.com/datasetfiles/Party_Manifestos_CAP_Web_csv.csv'
j= Jnry(country= 'Spain', path_to_file=path_to_file, source='CAP')
CAP_spain = j.merge_party_facts_with_target()
CAP_spain.head()
# Out:
# INFO:root:Processing a CAP file with data from Spain.
# INFO:root:exact and fuzzy matching will start now for the following target data:
# INFO:root:['PP : 1996.0', 'PP : 2000.0', 'PSOE : 1982.0', 'PSOE : 1986.0', 'PSOE : 1989.0', 'PSOE : 1993.0', 'PSOE : 2004.0', 'PSOE : 2008.0']
# INFO:root:Starting matching for PP.......
# INFO:root:the length of the slice of the partyfact data is: 97
# INFO:root:Exact matchPP <---> PP(= PF name)
# INFO:root:Starting matching for PP.......
# INFO:root:the length of the slice of the partyfact data is: 98
# INFO:root:Exact matchPP <---> PP(= PF name)
# INFO:root:Starting matching for PSOE.......
# INFO:root:the length of the slice of the partyfact data is: 89
# INFO:root:Exact matchPSOE <---> PSOE(= PF name)
# INFO:root:Starting matching for PSOE.......
# INFO:root:the length of the slice of the partyfact data is: 92
# INFO:root:Exact matchPSOE <---> PSOE(= PF name)
# INFO:root:Starting matching for PSOE.......
# INFO:root:the length of the slice of the partyfact data is: 95
# INFO:root:Exact matchPSOE <---> PSOE(= PF name)
# INFO:root:Starting matching for PSOE.......
# INFO:root:the length of the slice of the partyfact data is: 96
# INFO:root:Exact matchPSOE <---> PSOE(= PF name)
# INFO:root:Starting matching for PSOE.......
# INFO:root:the length of the slice of the partyfact data is: 99
# INFO:root:Exact matchPSOE <---> PSOE(= PF name)
# INFO:root:Starting matching for PSOE.......
# INFO:root:the length of the slice of the partyfact data is: 102
# INFO:root:Exact matchPSOE <---> PSOE(= PF name)
#    id    year politicalparty  majortopic  subtopic  \
# 0   1  1982.0           PSOE          20      2012
# 1   2  1982.0           PSOE          20      2012
# 2   3  1982.0           PSOE          20      2099
# 3   4  1982.0           PSOE          20      2099
# 4   5  1982.0           PSOE          20      2011
#
#                                        sentence text  jnry_year country_iso  \
# 0  Las próximas elecciones generales serán una bu...     1982.0         ESP
# 1  El 28 de octubre al tiempo que se elige a los ...     1982.0         ESP
# 2  La gran mayoría de los españoles es consciente...     1982.0         ESP
# 3  Los ciudadanos han constatado día a día cómo e...     1982.0         ESP
# 4  Por ello cuando las señales de agotamiento se ...     1982.0         ESP
#
#    partyfacts_id                    partyfacts_name partyfacts_name_short  \
# 0         1338.0  Partido Socialista Obrero Español                  PSOE
# 1         1338.0  Partido Socialista Obrero Español                  PSOE
# 2         1338.0  Partido Socialista Obrero Español                  PSOE
# 3         1338.0  Partido Socialista Obrero Español                  PSOE
# 4         1338.0  Partido Socialista Obrero Español                  PSOE
#
#            partyfacts_name_english  \
# 0  Spanish Socialist Workers Party
# 1  Spanish Socialist Workers Party
# 2  Spanish Socialist Workers Party
# 3  Spanish Socialist Workers Party
# 4  Spanish Socialist Workers Party
#
#                                            wikipedia type_of_match certainty  \
# 0  https://en.wikipedia.org/wiki/Spanish_Socialis...         exact      None
# 1  https://en.wikipedia.org/wiki/Spanish_Socialis...         exact      None
# 2  https://en.wikipedia.org/wiki/Spanish_Socialis...         exact      None
# 3  https://en.wikipedia.org/wiki/Spanish_Socialis...         exact      None
# 4  https://en.wikipedia.org/wiki/Spanish_Socialis...         exact      None
#
#   match_found_with_pf_column
# 0                 name_short
# 1                 name_short
# 2                 name_short
# 3                 name_short
# 4                 name_short
